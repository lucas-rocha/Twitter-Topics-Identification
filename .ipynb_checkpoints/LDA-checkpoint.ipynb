# %%
documents = []

ego_id = '40379006'

file = open('Textos para testes/egos/' + ego_id + '.txt', 'r', encoding='utf-8')
for line in file:
    documents.append(line)
file.close()

file = open('Textos para testes/alters/' + ego_id + '.txt', 'r', encoding='utf-8')
for line in file:
    documents.append(line)
file.close()
print(len(documents))
# Out:
# 2719

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

no_features = 1000 # max number of uniq words

tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
from sklearn.decomposition import LatentDirichletAllocation

no_topics = 10
learning_decay = .7
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0,learning_decay = learning_decay).fit(tf)

# %%
import numpy as np
import pandas as pd

# Show top n keywords for each topic
def show_topics(vectorizer=tf_vectorizer, lda_model=lda, n_words=20):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

topic_keywords = show_topics(vectorizer=tf_vectorizer, lda_model=lda, n_words=12)        

# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#          Word 0    Word 1  Word 2  Word 3         Word 4     Word 5    Word 6  \
# Topic 0     day   success     don     use          great     repeat   efforts
# Topic 1      eh      mean     god     act           ella      think  umbrella
# Topic 2     say       god    like    play        leaders      faith      lead
# Topic 3      gt      time  classy  little         ladies       want       new
# Topic 4     new    people    read    stop  circumstances      power        pt
# Topic 5     man  proverbs  humble   shall             10       goal   leaders
# Topic 6   jesus      life    plan    baby           love        way      come
# Topic 7     god      love    life    good           time      trust   matthew
# Topic 8  church      gift    best    life          girls  sacrifice    summer
# Topic 9    help     light    word    need          write      outro     intro
#
#                   Word 7     Word 8     Word 9     Word 10  Word 11
# Topic 0            small        new        sum     collier   robert
# Topic 1  disappointments    destiny  fortitude  accomplish  destroy
# Topic 2             goal       come   elevated  revelation    alpha
# Topic 3         bracelet   checkout         rt      beauty     girl
# Topic 4           really         ps       lord     stephen    curry
# Topic 5             seek     spirit       self         god    wrong
# Topic 6             lord      faith     answer      christ     know
# Topic 7           change       gift       stay        live    place
# Topic 8         checkout         gt   elevated     looking    faith
# Topic 9           killer  forgiving    enemies        path      105

# %%
# column names
topicnames = ["Topic" + str(i) for i in range(no_topics)]

# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(np.round(lda.components_, 2))

# Assign Column and Index
df_topic_keywords.columns = tf_vectorizer.get_feature_names()
df_topic_keywords.index = topicnames

# Vie
#list_frames = []
for t, row in df_topic_keywords.iterrows():
    aux = row.nlargest(12)
    #list_frames.append(aux.to_frame().T)
    print(t)
    a = ''
    for word, weight in aux.items():
        a += ' ' + word + ' (' + str(weight) + ') |'
    print(a)
    print('\n')

#list_frames[1]
# Out:
# Topic0
#  day (12.37) | success (6.06) | don (5.79) | use (5.38) | great (4.47) | repeat (3.96) | efforts (3.94) | small (3.94) | new (3.92) | sum (3.9) | collier (3.89) | robert (3.87) |
#
#
# Topic1
#  eh (12.2) | mean (8.09) | god (6.96) | act (6.92) | ella (5.75) | think (5.37) | umbrella (3.64) | disappointments (3.31) | destiny (3.3) | fortitude (3.3) | accomplish (3.29) | destroy (3.28) |
#
#
# Topic2
#  say (11.13) | god (7.91) | like (7.81) | play (7.68) | leaders (7.61) | faith (6.61) | lead (6.52) | goal (6.42) | come (6.11) | elevated (5.64) | revelation (5.58) | alpha (5.56) |
#
#
# Topic3
#  gt (24.5) | time (14.57) | classy (11.03) | little (9.09) | ladies (9.08) | want (5.71) | new (5.41) | bracelet (5.4) | checkout (5.37) | rt (5.25) | beauty (5.2) | girl (5.07) |
#
#
# Topic4
#  new (12.48) | people (11.81) | read (9.39) | stop (6.25) | circumstances (6.22) | power (6.21) | pt (5.4) | really (5.18) | ps (5.01) | lord (4.91) | stephen (4.86) | curry (4.84) |
#
#
# Topic5
#  man (12.97) | proverbs (8.25) | humble (6.78) | shall (6.2) | 10 (6.07) | goal (4.61) | leaders (4.58) | seek (4.39) | spirit (4.38) | self (4.35) | god (3.98) | wrong (3.92) |
#
#
# Topic6
#  jesus (10.87) | life (6.24) | plan (5.8) | baby (5.22) | love (4.67) | way (4.57) | come (4.51) | lord (4.41) | faith (3.91) | answer (3.86) | christ (3.8) | know (3.52) |
#
#
# Topic7
#  god (55.42) | love (15.58) | life (12.01) | good (10.97) | time (8.18) | trust (7.8) | matthew (7.3) | change (7.02) | gift (6.26) | stay (5.96) | live (5.86) | place (5.59) |
#
#
# Topic8
#  church (7.51) | gift (7.01) | best (6.76) | life (5.14) | girls (4.82) | sacrifice (3.92) | checkout (3.52) | summer (3.52) | elevated (3.51) | gt (3.51) | faith (3.5) | looking (3.5) |
#
#
# Topic9
#  help (10.1) | light (4.26) | word (4.01) | need (3.63) | write (3.61) | outro (3.6) | intro (3.57) | killer (3.56) | forgiving (3.34) | enemies (3.29) | path (2.75) | 105 (2.74) |

# %%
# Create Document - Topic Matrix
lda_output = lda.transform(tf)

# index names
docnames = [str(i) for i in range(len(documents))]

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 6), columns=topicnames, index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

# Styling
def color_green(val):
   color = 'green' if val > .1 else 'black'
   return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# Apply Style
style = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
style
# Out:
# <style  type="text/css" >
#     #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow0_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col2 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow1_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow2_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow3_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow4_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col2 {
#             color:  green;
#             font-weight:  700;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb671frow5_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_058d681e_df6f_11e8_9f98_782bcbeb

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution
# Out:
#    Topic Num  Num Documents
# 0          7             92
# 1          4             67
# 2          2             58
# 3          3             54
# 4          6             40
# 5          5             38
# 6          8             36
# 7          0             31
# 8          1             27
# 9          9             21

# %%
#Documents of topic that classified most documents (First on the table above)

dominant_topic = df_document_topic['dominant_topic']

topic = df_topic_distribution['Topic Num'][0]

test_text = []
j = 0
for i, doc in enumerate(dominant_topic):
    if doc == topic:
        j+=1
        print('- ' + documents[i] + '  ')
        test_text.append(documents[i])
# Out:
# - GOD PLAN LIFE GT YOUR PLAN LIFE
#
# - FOR KNOW PLAN PLAN PROSPER HARM
#
# - FRIENDSHIPS CONVERSATIONS W PPL LOOK LIKE GREATEST AVENUE 2 BEGIN UNDERSTAND MINORITY EXPER
#
# - IF TALK DEATH CHRIST MUCH TALK DEATH GLENN COULD PROBABLY SAVE FOLKS JOH
#
# - THE LORD STRONGHOLD LIFE SHALL I AFRAID
#
# - I WISH BABY REALLY BABY REALLY BABY WOULD STOP PLAYIN DUMB BABY
#
# - FOR I KNOW PLAN I DECLARE LORD PLAN PROSPER HARM PLAN GIVE HOPE FUTURE JER 29 11
#
# - WHO SPEAK LOUDLY REALLY REASON WORD
#
# - FOR I KNOW PLAN I DECLARE LORD PLAN PROSPER HARM PLAN GIVE HOPE FUTURE JER 29 11
#
# - JESUS CHRIST ENDURE EVER IMAGINE CHANCE RELATIONSHIP US
#
# - ABOVE LOVE DEEPLY LOVE COVER MULTITUDE SIN 1PETER 4 8
#
# - KEEP PRAY FAITH PRAYER DEVELOP WONDERFUL QUALITIES SOUL MYRTLE FILLMORE
#
# - HE PLAYS HALLELUJAH ON CRYSTAL GLASSES OF WATER AND IT SOUNDS HEAVENLY
#
# - JESUS ANSWER I WAY TRUTH LIFE NO ONE COME FATHER EXCEPT JOHN 14 6
#
# - THE MINISTRY LORD GIVE US QUICKLY BECOME IDOL BREAK US
#
# - I WISH BABY REALLY BABY REALLY BABY WOULD STOP PLAYIN DUMB BABY
#
# - KEEP PRAY FAITH PRAYER DEVELOP WONDERFUL QUALITIES SOUL MYRTLE FILLMORE
#
# - HE PLAYS HALLELUJAH ON CRYSTAL GLASSES OF WATER AND IT SOUNDS HEAVENLY
#
# - JESUS ANSWER I WAY TRUTH LIFE NO ONE COME FATHER EXCEPT JOHN 14 6
#
# - GRACE SEE FAILURES MISTAKE SIN OVERWHELM FORGIVENESS LOVE FAVOUR ALL SUFFICIENT GRACE
#
# - YOUR LIFE OPPORTUNITY MISS WIDE EYE ALIVE ALERT READY EVERY OPPORTUNITY COME WAY
#
# - FOLLOWING JESUS LIFE FAITH LIFE SMALLNESS THE NARROW GATE NAME NAME JESUS THERE NAME
#
# - WITHOUT JESUS HOPELESS END WITH JESUS ENDLESS HOPE
#
# - HOPE CONFIDENT EXPECTATION WHAT EXPECTATION CONFIDENCE FIRMLY FOUND JESUS
#
# - AVAILABLE WHEREVER BOOK SELL WHO COULD BLESS CHRISTMAS
#
# - WHAT GREAT GOD SERVE JESUS ANSWER ALWAYS JESUS
#
# - HE PLAYS HALLELUJAH ON CRYSTAL GLASSES OF WATER AND IT SOUNDS HEAVENLY
#
# - INDEED MAKE MANY MISTAKE COULD CONTROL TONGUE WOULD PERFECT COULD CONTROL EVERY WAY
#
# - A LARGE PART AMERICA KNOW COME LAST NAME AFRICAN AMERICANS KNOW BELONG LAST NAME
#
# - THE MINISTRY LORD GIVE US QUICKLY BECOME IDOL BREAK US
#
# - JESUS CHRIST ENDURE EVER IMAGINE CHANCE RELATIONSHIP US
#
# - ABOVE LOVE DEEPLY LOVE COVER MULTITUDE SIN 1PETER 4 8
#
# - KEEP PRAY FAITH PRAYER DEVELOP WONDERFUL QUALITIES SOUL MYRTLE FILLMORE
#
# - JESUS ANSWER I WAY TRUTH LIFE NO ONE COME FATHER EXCEPT JOHN 14 6
#
# - JESUS CHRIST ENDURE EVER IMAGINE CHANCE RELATIONSHIP US
#
# - ABOVE LOVE DEEPLY LOVE COVER MULTITUDE SIN 1PETER 4 8
#
# - KEEP PRAY FAITH PRAYER DEVELOP WONDERFUL QUALITIES SOUL MYRTLE FILLMORE
#
# - HE PLAYS HALLELUJAH ON CRYSTAL GLASSES OF WATER AND IT SOUNDS HEAVENLY
#
# - JESUS ANSWER I WAY TRUTH LIFE NO ONE COME FATHER EXCEPT JOHN 14 6
#
# - JESUS CHRIST LORD SWEAR WORD

# %%
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer, mds='tsne')
panel
# Out:
# c:\users\pc-dell\appdata\local\programs\python\python36\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 7      194.108276   68.651138       1        1  18.533344
# 2        7.886019  -92.360916       2        1  12.685210
# 5     -146.505096  -35.388447       3        1  11.729363
# 4       54.453369  138.337021       4        1  11.433253
# 3     -103.226372  126.015915       5        1  10.322515
# 6       74.081238 -201.236847       6        1   9.692414
# 0      177.669586  -97.870110       7        1   7.642674
# 8      -29.888914   24.899712       8        1   7.350214
# 1       90.376526   -1.144811       9        1   6.341992
# 9      -91.103645 -171.967102      10        1   4.269020, topic_info=     Category       Freq        Term      Total  loglift  logprob
# term
# 206   Default  67.000000         god  67.000000  30.0000  30.0000
# 218   Default  28.000000          gt  28.000000  29.0000  29.0000
# 480   Default  20.000000        time  20.000000  28.0000  28.0000
# 148   Default   9.000000          eh   9.000000  27.0000  27.0000
# 114   Default  12.000000         day  12.000000  26.0000  26.0000
# 230   Default   8.000000        help   8.000000  25.0000  25.0000
# 296   Default  12.000000         man  12.000000  24.0000  24.0000
# 317   Default  19.000000         new  19.000000  23.0000  23.0000
# 94    Default  12.000000      classy  12.000000  22.0000  22.0000
# 252   Default  14.000000       jesus  14.000000  21.0000  21.0000
# 340   Default  12.000000      people  12.000000  20.0000  20.0000
# 277   Default  20.000000        life  20.000000  19.0000  19.0000
# 298   Default   7.000000        mean   7.000000  18.0000  18.0000
# 414   Default  11.000000         say  11.000000  17.0000  17.0000
# 198   Default  15.000000        gift  15.000000  16.0000  16.0000
# 283   Default   8.000000      little   8.000000  15.0000  15.0000
# 262   Default   8.000000      ladies   8.000000  14.0000  14.0000
# 23    Default   7.000000         act   7.000000  13.0000  13.0000
# 56    Default   9.000000        best   9.000000  12.0000  12.0000
# 386   Default   9.000000        read   9.000000  11.0000  11.0000
# 91    Default  12.000000      church  12.000000  10.0000  10.0000
# 375   Default  11.000000    proverbs  11.000000   9.0000   9.0000
# 478   Default   7.000000       think   7.000000   8.0000   8.0000
# 290   Default  24.000000        love  24.000000   7.0000   7.0000
# 151   Default   5.000000        ella   5.000000   6.0000   6.0000
# 461   Default   6.000000     success   6.000000   5.0000   5.0000
# 173   Default  13.000000       faith  13.000000   4.0000   4.0000
# 85    Default   8.000000    checkout   8.000000   3.0000   3.0000
# 69    Default   8.000000    bracelet   8.000000   2.0000   2.0000
# 350   Default   8.000000        play   8.000000   1.0000   1.0000
# ...       ...        ...         ...        ...      ...      ...
# 331   Topic10   1.586623       outro   4.116811   2.2003  -4.3348
# 249   Topic10   1.571696       intro   4.111076   2.1923  -4.3442
# 188   Topic10   1.472451   forgiving   3.894031   2.1813  -4.4094
# 257   Topic10   1.569836      killer   4.190181   2.1720  -4.3454
# 181   Topic10   1.197141        feet   3.531667   2.0720  -4.6164
# 264   Topic10   1.187083        lamp   3.576970   2.0508  -4.6249
# 335   Topic10   1.213904        path   3.681828   2.0442  -4.6025
# 139   Topic10   1.175250       dress   3.570816   2.0425  -4.6349
# 1     Topic10   1.205745         105   3.696790   2.0334  -4.6093
# 256   Topic10   0.881546        kick   3.393733   1.8058  -4.9224
# 514   Topic10   1.766778        word   6.878206   1.7946  -4.2272
# 159   Topic10   1.450044     enemies   5.785441   1.7700  -4.4248
# 172   Topic10   0.691742        fact   3.144179   1.6397  -5.1649
# 378   Topic10   1.184599       psalm   5.964793   1.5373  -4.6270
# 3     Topic10   1.197959         119   6.039344   1.5361  -4.6157
# 208   Topic10   0.713664      gospel   3.688714   1.5112  -5.1337
# 385   Topic10   0.599130        rain   3.226272   1.4702  -5.3086
# 86    Topic10   0.644807       child   3.565632   1.4436  -5.2352
# 363   Topic10   0.708707      preach   4.004608   1.4220  -5.1407
# 315   Topic10   1.600406        need   9.186070   1.4064  -4.3261
# 231   Topic10   0.664538        high   3.846742   1.3979  -5.2050
# 65    Topic10   0.447337        blow   3.432135   1.1162  -5.6008
# 509   Topic10   0.456574       white   3.521298   1.1110  -5.5804
# 306   Topic10   0.436470    minority   3.372326   1.1091  -5.6254
# 494   Topic10   0.463106  understand   3.741410   1.0645  -5.5662
# 34    Topic10   0.461158     america   3.793242   1.0466  -5.5704
# 136   Topic10   0.397166        dope   3.421665   1.0003  -5.7198
# 57    Topic10   0.935562      better  10.067332   0.7779  -4.8630
# 360   Topic10   0.671043        pray   9.333182   0.5213  -5.1953
# 82    Topic10   0.538221      change   9.298240   0.3045  -5.4159
#
# [418 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 0         3  0.568508          10
# 0         4  0.227403          10
# 1        10  0.270505         105
# 3         3  0.496743         119
# 3        10  0.165581         119
# 5         4  0.188469          14
# 5         6  0.376938          14
# 8         5  0.270492          18
# 8         9  0.270492          18
# 9         9  0.300400          19
# 10        6  0.492445      1peter
# 11        1  0.641956          22
# 12        3  0.514560          23
# 12        4  0.171520          23
# 13        3  0.584029          24
# 14        2  0.667303          27
# 15        3  0.518244          29
# 15        6  0.172748          29
# 16        4  0.221870          30
# 16        7  0.221870          30
# 19        1  0.566700          37
# 20        1  0.568617     ability
# 22        8  0.218506  accomplish
# 22        9  0.437011  accomplish
# 23        2  0.254953         act
# 23        9  0.509906         act
# 24        2  0.450157      action
# 25        2  0.489180        adam
# 27        2  0.171376      afraid
# 27        6  0.171376      afraid
# ...     ...       ...         ...
# 500       4  0.363704       votes
# 500       5  0.181852       votes
# 502       1  0.107272        want
# 502       2  0.107272        want
# 502       5  0.429090        want
# 502       7  0.214545        want
# 503       1  0.585069       watch
# 503       9  0.146267       watch
# 504       6  0.362413       water
# 504       8  0.181207       water
# 505       6  0.495247         way
# 507       2  0.489031     welcome
# 508       1  0.590544     whisper
# 509       8  0.283986       white
# 511       3  0.587924        wise
# 513       6  0.423927   wonderful
# 514       1  0.145387        word
# 514       2  0.145387        word
# 514       6  0.145387        word
# 514      10  0.290774        word
# 515       1  0.521221        work
# 516       1  0.440447       world
# 516       4  0.146816       world
# 516       8  0.146816       world
# 518       1  0.223510       worth
# 518       7  0.447020       worth
# 519      10  0.491258       write
# 520       3  0.530049       wrong
# 522       2  0.278449         yes
# 522       4  0.417674         yes
#
# [553 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[8, 3, 6, 5, 4, 7, 1, 9, 2, 10])

# %%
# Construct the k-means clusters
from sklearn.cluster import KMeans
clusters = KMeans(n_clusters=15, random_state=100).fit_predict(lda_output)

# Build the Singular Value Decomposition(SVD) model
from sklearn.decomposition import TruncatedSVD
svd_model = TruncatedSVD(n_components=2)  # 2 components
lda_output_svd = svd_model.fit_transform(lda_output)

# X and Y axes of the plot using SVD decomposition
x = lda_output_svd[:, 0]
y = lda_output_svd[:, 1]

# Plot
plt.figure(figsize=(12, 12))
plt.scatter(x, y, c=clusters)
plt.xlabel('Component 2')
plt.xlabel('Component 1')
plt.title("Segregation of Topic Clusters", )
# Out:
# Text(0.5,1,'Segregation of Topic Clusters')

# %%
#Vectorize transform
text = tf_vectorizer.transform(test_text)

#LDA Transform
topic_probability_scores = lda.transform(text)

for i, doc in enumerate(topic_probability_scores):
    if not np.argmax(doc) == topic:
        print ('Document ' + str(i) + ':')
        print(np.argmax(doc))
        print(test_text[i])
        print(doc)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += "  ".join([feature_names[i]
                            for i in topic.argsort()[:-no_top_words - 1:-1]])
        print(message)
    print()

no_top_words = 12
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic #0: day  success  don  use  great  repeat  efforts  small  new  sum  collier  robert
# Topic #1: eh  mean  god  act  ella  think  umbrella  disappointments  destiny  fortitude  accomplish  destroy
# Topic #2: say  god  like  play  leaders  faith  lead  goal  come  elevated  revelation  alpha
# Topic #3: gt  time  classy  little  ladies  want  new  bracelet  checkout  rt  beauty  girl
# Topic #4: new  people  read  stop  circumstances  power  pt  really  ps  lord  stephen  curry
# Topic #5: man  proverbs  humble  shall  10  goal  leaders  seek  spirit  self  god  wrong
# Topic #6: jesus  life  plan  baby  love  way  come  lord  faith  answer  christ  know
# Topic #7: god  love  life  good  time  trust  matthew  change  gift  stay  live  place
# Topic #8: church  gift  best  life  girls  sacrifice  summer  checkout  gt  elevated  looking  faith
# Topic #9: help  light  word  need  write  outro  intro  killer  forgiving  enemies  path  105

# %%
new_documents = []
threshold = .8
for index, row in df_document_topic.iterrows():
    best_topic = row['dominant_topic']
    column = 'Topic'+str(int(best_topic))
    if row[column] >= threshold:
        new_documents.append(documents[int(index)])
        
print(len(new_documents))
documents = new_documents
# Out:
# 464
