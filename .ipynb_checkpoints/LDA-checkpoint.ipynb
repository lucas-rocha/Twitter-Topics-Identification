# %%
documents = []

ego_id = '40379006'

file = open('Textos para testes/egos/' + ego_id + '.txt', 'r', encoding='utf-8')
for line in file:
    documents.append(line)
file.close()

file = open('Textos para testes/alters/' + ego_id + '.txt', 'r', encoding='utf-8')
for line in file:
    documents.append(line)
file.close()
print(len(documents))
# Out:
# 2719

# %%
documents1 = []
j = 0
for t in documents:
    if not t in documents1:
        documents1.append(t)
    else:
        j+=1
        #print(t)
print('Numero de textos repetidos: ' + str(j))
# Out:
# Numero de textos repetidos: 142

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

no_features = 1000 # max number of uniq words

tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
from sklearn.decomposition import LatentDirichletAllocation

no_topics = 10
learning_decay = .7
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0,learning_decay = learning_decay).fit(tf)

# %%
import numpy as np
import pandas as pd

# Show top n keywords for each topic
def show_topics(vectorizer=tf_vectorizer, lda_model=lda, n_words=20):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

topic_keywords = show_topics(vectorizer=tf_vectorizer, lda_model=lda, n_words=12)        

# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#          Word 0   Word 1   Word 2    Word 3  Word 4  Word 5  Word 6    Word 7  \
# Topic 0    time      new   people      talk    live  listen  forget      word
# Topic 1     god  leaders     goal      know    come     way    mean      need
# Topic 2    like     make      god      good    life    live  follow     think
# Topic 3  people      try     want       don    tell   build      pt  tomorrow
# Topic 4    best  retweet     vote    little  matter   curry   story    ladies
# Topic 5    love     mind    stand       sin  person    hate  people      year
# Topic 6   watch     wait  believe  umbrella   gonna      eh      30     round
# Topic 7   video   better     help       say   faith    real    lord     psalm
# Topic 8    stay     game     fall       win    play   heart  happen        23
# Topic 9     day      yes    great      sure   today     let   right   tonight
#
#           Word 8   Word 9 Word 10  Word 11
# Topic 0     hard  forgive   check     days
# Topic 1   things   church  change    world
# Topic 2    happy     feel   start       rt
# Topic 3    power     know     use    tweet
# Topic 4     hear       ur   music  welcome
# Topic 5     like      say     god    jesus
# Topic 6    store    hours     1st     step
# Topic 7  looking      new    room     fear
# Topic 8    break    leave  alyssa    shall
# Topic 9     read       ps    join      don

# %%
# column names
topicnames = ["Topic" + str(i) for i in range(no_topics)]

# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(np.round(lda.components_, 2))

# Assign Column and Index
df_topic_keywords.columns = tf_vectorizer.get_feature_names()
df_topic_keywords.index = topicnames

# Vie
#list_frames = []
for t, row in df_topic_keywords.iterrows():
    aux = row.nlargest(12)
    #list_frames.append(aux.to_frame().T)
    print(t)
    a = ''
    for word, weight in aux.items():
        a += ' ' + word + ' (' + str(weight) + ') |'
    print(a)
    print('\n')

#list_frames[1]
# Out:
# Topic0
#  time (84.32) | new (64.03) | people (48.23) | talk (36.12) | live (27.59) | listen (26.96) | forget (23.65) | word (22.78) | hard (21.24) | forgive (16.9) | check (16.44) | days (16.33) |
#
#
# Topic1
#  god (169.63) | leaders (70.6) | goal (66.03) | know (64.67) | come (63.25) | way (46.55) | mean (44.49) | need (41.85) | things (40.77) | church (38.92) | change (35.37) | world (33.7) |
#
#
# Topic2
#  like (90.4) | make (85.53) | god (83.69) | good (78.53) | life (76.65) | live (66.36) | follow (44.15) | think (41.08) | happy (40.83) | feel (39.18) | start (37.14) | rt (34.38) |
#
#
# Topic3
#  people (58.28) | try (36.27) | want (34.81) | don (34.04) | tell (30.64) | build (29.18) | pt (24.59) | tomorrow (24.43) | power (22.14) | know (21.71) | use (21.35) | tweet (18.01) |
#
#
# Topic4
#  best (59.04) | retweet (40.48) | vote (24.73) | little (24.67) | matter (22.02) | curry (21.25) | story (19.98) | ladies (17.48) | hear (16.67) | ur (15.75) | music (15.48) | welcome (15.11) |
#
#
# Topic5
#  love (193.89) | mind (26.67) | stand (23.62) | sin (22.93) | person (21.6) | hate (18.55) | people (18.25) | year (16.95) | like (16.7) | say (16.59) | god (15.91) | jesus (15.76) |
#
#
# Topic6
#  watch (53.95) | wait (29.64) | believe (24.58) | umbrella (17.9) | gonna (12.62) | eh (11.89) | 30 (10.04) | round (9.67) | store (8.96) | hours (8.65) | 1st (8.39) | step (8.07) |
#
#
# Topic7
#  video (39.59) | better (37.99) | help (32.8) | say (29.62) | faith (26.81) | real (23.32) | lord (21.48) | psalm (18.51) | looking (18.42) | new (18.04) | room (15.54) | fear (14.82) |
#
#
# Topic8
#  stay (34.27) | game (24.78) | fall (24.62) | win (21.65) | play (18.02) | heart (17.4) | happen (17.32) | 23 (16.6) | break (14.82) | leave (12.29) | alyssa (12.22) | shall (11.13) |
#
#
# Topic9
#  day (99.46) | yes (56.04) | great (50.3) | sure (44.62) | today (44.14) | let (42.47) | right (39.23) | tonight (33.92) | read (25.27) | ps (21.65) | join (20.6) | don (19.27) |

# %%
# Create Document - Topic Matrix
lda_output = lda.transform(tf)

# index names
docnames = [str(i) for i in range(len(documents))]

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 6), columns=topicnames, index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

# Styling
def color_green(val):
   color = 'green' if val > .1 else 'black'
   return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# Apply Style
style = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
style
# Out:
# <style  type="text/css" >
#     #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow0_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col2 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow1_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col9 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow2_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow3_col10 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow4_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col6 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb671frow5_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_54f62cca_e12f_11e8_b1e1_782bcbeb

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution
# Out:
#    Topic Num  Num Documents
# 0          2            472
# 1          1            469
# 2          0            362
# 3          9            341
# 4          5            227
# 5          4            194
# 6          7            190
# 7          3            177
# 8          8            166
# 9          6            121

# %%
#Documents of topic that classified most documents (First on the table above)

dominant_topic = df_document_topic['dominant_topic']

topic = df_topic_distribution['Topic Num'][0]

test_text = []
j = 0
for i, doc in enumerate(dominant_topic):
    if doc == 1:
        j+=1
        print('- ' + documents[i] + '  ')
        test_text.append(documents[i])
# Out:
# - THE VOICE 2017 BLIND AUDITION MISSY ROBERTSON SCARS YOUR BEAUTIFUL
#
# - LIGHT FIRE INSIDE YOU SEED ALMIGHTY GOD DON ALLOW SOMETHING SMALL KEEP GOD BEST
#
# - WALK GIFT CALL DON COMPARE OTHERS GOD NEED YOU
#
# - LEADERS GOAL SHUT BACKGROUND NOISE LISTEN VOICE CHALLENGE STRETCH INSPIRE G
#
# - THE RIGHTEOUSNESS COME GOD FAITH PHIL 3 9
#
# - GOD PLAN LIFE GT YOUR PLAN LIFE
#
# - BE CONTENT GOD SAY NEVER I LEAVE NEVER I FORSAKE HEBREWS 13 5
#
# - A TRUE CANADIAN DELICACY NEED WHAT TOPPINGS PREFER
#
# - I GON PRAISE PRAISE TIL I GO
#
# - EVERYONE COME SUPPORT TONIGHT
#
# - TIME GET FUNNY WAY TICK THINGS MUCH DIFFERENT
#
# - JUST SEE GO ANYMORE MEAN GOD CHANGE DESTINATION
#
# - YOU CERTAINLY CARRY GOD PURPOSE HOWEVER ACT MAKE DIFFERENCE WHETHER SERVE LIKE JUD
#
# - GOD PLAN BIGGER MISTAKE
#
# - BREAKING NEWS WHY LEAVE NIKE SEE RESPONSE FIRST TIME
#
# - GOD ALWAYS
#
# - AS CHILD GOD I RESPOND LIFE COURAGE STRENGTH VICTORY WE CREATE OVERCOMERS LIVE
#
# - BELONG WHAT EVEN MEAN
#
# - GOD CONSIDER HOPELESS IF HE HE WOULD MOVE SEEK HIM HE OBVIOUSLY
#
# - WE DIVINE WORK ART SOMETHING GOD MAKE SOMETHING HE SATISFY C
#
# - DO JUDGE JUDGE MATTHEW 7 1
#
# - IN THEORY FLAW IN REALITY BEAUTIFUL
#
# - FOR KNOW PLAN PLAN PROSPER HARM
#
# - DO CONFORM PATTERN WORLD TRANSFORMED RENEW MIND
#
# - IT BEST EVEN TOUGHEST DAYS KNOW EXACTLY GOD MAKE
#
# - TO SAY THING REALLY MEAN NOTHING LESS REALLY MEAN WHOLE ART
#
# - THE EFFECTIVE WAY AMELIA EARHART
#
# - A WRITER RECOUNT STEP COMFORT ZONE THAILAND
#
# - LUST POOR WEAK WHIMPER THING COMPARE RICHNESS ENERGY DESIRE ARISE LUST BEE
#
# - I PRAY I HELP I PRAY I HELPLESS IT CHANGE GOD CHANGE CSLEWIS
#
# - 1 2 OF COURSE GOD CONSIDER HOPELESS IF HE HE WOULD MOVE SEEK HIM HE OBVIOUSLY
#
# - EVERY TIME I GET ZILLOW EMAIL HOUSE AREA I WEEP CONSIDER MOVE SOMEWHERE LIKE DETROIT HOUSE AR
#
# - BRIANCHOUSTON LEADERS GOAL TO EQUIP EMPOWER EVERYONE LEAD GOD CALL
#
# - IT WARM MEAN TAN SKIN HAIR STILL FULL EFFECT
#
# - DON COUNT THINGS THINGS COUNT ZIG ZIGLAR
#
# - ABSOLUTELY AWE WAY GOD WORK
#
# - THIS CHRISTMAS HELP MAKE DIFFERENCE FOSTER CHILD LIFE DONATE NEW WARM COAT WE NEED 67
#
# - BECAUSE AWAKE HOUR NEED FREAK CHEER LIFE EVEN OCTOBER
#
# - I CHANGE FACT I MAKE MISTAKE I CHANGE I LOOK I RECIEVE
#
# - GET GET PRAY A PERSON INTIMATE GOD NEVER INTIMIDATE MEN LEONARD RAVENHILL
#
# - THE BEST THINGS US USUALLY THINGS INTEREST US
#
# - THE PROCESS PRODUCT PROGRESSION CHURCH CLOTHES
#
# - CREATE COME SEE CULTURE CHURCH
#
# - WHEN LAUNDRY KNOW KEEPER
#
# - YOU SURPRISE GOD HE KNOW HE GET HE GET
#
# - IT FUNNY PEOPLE KNOW LEAST ALWAYS SAY
#
# - RT DISAPPOINTMENTS GOD WAY SAY I GET SOMETHING BETTER STORE
#
# - CHRIS BLUE AUDITION PERFECT WAY END
#
# - SORRY SPEAK TRUTH WELCOME
#
# - BLAKESHELTON COMIN SUPPORT FTW VOICE SKILLS
#
# - IF KNOW MEAN RETWEET WELCOME TEAM
#
# - THE BLIND AUDITION END ONE AMAZE MOMENTS EVER
#
# - NEED U RIGHT RETWEET
#
# - THAT A CAPPELLA MOMENT SO OBSESS INCREDIBLE TAKE HOUSE OF THE RISING SUN
#
# - WHEN GOD WRECK PLAN KNOW HIS PLAN MUCH BETTER TRUST HIM EVEN HARDEST EVERYTHING WORK
#
# - GOD FAITHFUL HE PROVIDE EVEN THINGS LOOK IMPOSSIBLE TODAY PUT TRUST HIM WATCH HIM WORK LIFE
#
# - GOD PLAN EVERYTHING THE GOOD BAD PAIN JOY GOD REASON HE PLAN PURPOSE
#
# - IF KNOW MEAN RETWEET WELCOME TEAM
#
# - YOUR PAIN STRUGGLE TEMPORARY HOLD HOPE GOD PROVIDE KNOW GET ANYTHING HIM
#
# - IF KNOW MEAN RETWEET WELCOME TEAM
#
# - GO DAY TODAY KNOW GOD LET HIM LEAD GUIDE DAY ALL THINGS POSSIBLE HIM
#
# - GOD FAITHFUL HE PROVIDE EVEN THINGS LOOK IMPOSSIBLE TODAY PUT TRUST HIM WATCH HIM WORK LIFE
#
# - O LORD I HONOR PRAISE NAME GOD ISAIAH 25 1
#
# - BEAUTIFUL
#
# - I EVEN KNOW CHALLENGE I WANT RAP BEAT
#
# - FOR I KNOW PLAN I DECLARE LORD PLAN PROSPER HARM PLAN GIVE HOPE FUTURE JER 29 11
#
# - IF MEAN
#
# - I FEEL GOD BIGGER PLAN SAY CHRISTOPHER NORTON WALK FIRST TIME FOUR YEARS SPORT INJURY
#
# - GOD BIGGER PLAN I
#
# - WHO SPEAK LOUDLY REALLY REASON WORD
#
# - GOD WAY PERFECT ALL LORD PROMISE PROVE TRUE HE SHIELD LOOK HIM PROTECTION PSALM 18 30
#
# - YOUR VALUE NEVER MEASURE PHYSICAL MATERIAL THINGS
#
# - CHURCH WHERE MANY LEAN TIME ENERGY FAITHFULNESS COMMITMENT BLESS OTHERS BRING GLORY GOD
#
# - CHURCH WHERE FOCUS LEAN PRESENCE START END LIFT ATMOSPHERE IMPACT AROUND
#
# - LEADERS GOAL HAVE NEED CONVERSATIONS ADDRESS OVERDUE ISSUE PROCRASTINATION IGNORE MAKE GO AWAY
#
# - JESUS ALIVE
#
# - IF KNOW MEAN RETWEET WELCOME TEAM
#
# - CHRISTIANITY COME RULE COME CHARACTERISTICS GOD SUPPOSE STRIVE ACHIEVE
#
# - Y CHOOSE MAKEUP FREE MEAN I ANTI MAKEUP DO
#
# - I GIVE GOD TRUST MAKE SOMETHING BEAUTIFUL
#
# - NO SITUATION HOPELESS GOD HE PROVIDE HOPE SEEM NONE KEEP TRUST HIM WATCH HIM WORK LIFE
#
# - TAKE LIFE I I KNOW MUCH GIVE OFFER BRING GOD
#
# - FROM BOTTOM TOP YOU PERFECT
#
# - FROM BOTTOM TOP YOU PERFECT
#
# - ABSOLUTELY
#
# - TAKE 3 1 SERIES LEAD
#
# - YESTERDAY FAMILY TEAM W PROVIDE 400 LOCAL FAMILIES
#
# - I MEAN
#
# - NEED DINNER PLAN SHOW MAKE QUINOA SALAD W GRILL CHICKEN
#
# - ANY TIME END SEASON LOSS TOUGH BUT LEAVE
#
# - SWAT LEAD ANOTHER SPLASH I CARE FORECAST SAY RAIN BROOKLYN RIGHT
#
# - CREATE COME SEE CULTURE CHURCH
#
# - THERE NEW IDEAS SUN PLENTY GOD IDEAS SUN
#
# - LORD I SURRENDER ALL ALL BLESSED SAVIOR I SURRENDER ALL
#
# - FAITH CHRIST THING SAVE DESPAIR FAITH HIM GOOD ACTION MUST INEVITABLY COME CSLEWIS
#
# - INDEED MAKE MANY MISTAKE COULD CONTROL TONGUE WOULD PERFECT COULD CONTROL EVERY WAY
#
# - WORSHIP LIFESTYLE PRAISE ATTITUDE
#
# - LET GO WORK
#
# - PROMISE RESIST DEVIL HE FLEE
#
# - IF GOD DO WAKE TODAY FULFILL PURPOSE
#
# - IF GOD SOVEREIGN NOTHING RANDOM
#
# - EVANGELICAL LEADERS ASK USE VOICE SPEAK RACIAL UNITY USE TALK RACISM
#
# - DON STAY GOD CALL WALK
#
# - WHATEVER DAY BRING NOTHING GOD HANDLE
#
# - WAY STAY TUNE
#
# - JUST WHOLE FOODS MEAN HEALTHY
#
# - IF GO ACKNOWLEDGE WORK MLK WEEKEND ACKNOWLEDGE WORK STILL NEED DO
#
# - I PRAY CELEBRATE MLK IGNORE LEGACY EQUALITY JUSTICE FIGHT
#
# - I REALLY HATE ALYSSA TEXTING MOM WITHOUT KNOW
#
# - IF KNOW MEAN RETWEET WELCOME TEAM
#
# - US END
#
# - JAY_QAY_LIN YOUR HERMOSA I EVEN KNOW CALL MOSQUITO
#
# - WAVE WAVE
#
# - ATHEISM TURN SIMPLE IF WHOLE UNIVERSE MEAN NEVER FIND MEAN
#
# - IF KNOW MEAN RETWEET WELCOME TEAM
# - SEE KNOW GET KEEP GLASS FANTASTIC WAY END NIGHT
#
# - I KNOW I EAT PIZZA 3 NIGHTS ROW BUT I MEAN REALLY GO MAKE MUCH DIFFERENCE I GONNA GO
#
# - GOD LET ACCEPT THINGS I CANT CHANGE COURAGE CHANGE THINGS I WISDOM KNOW DIFFERENCE
#
# - WAY QUICKLY ESTABLISH TRUST AUTHORITY W HIGHEST DO RIGHT 200
#
# - THE BOSSY GALS TAKE WORLD STORM DON LET WAVE PASS
#
# - BE DIFFERENCE
#
# - YOUR PLAN INCLUDE SEVERAL SOURCE STREAM TRAFFIC
#
# - CREATE START END MIND WORK WAY BACKWARDS
#
# - FREE LET US BOSS
#
# - APPROACH LET COME
#
# - COME BOSS
#
# - START DON STAND WAY
#
# - FROM BOTTOM TOP YOU PERFECT
#
# - ABSOLUTELY
#
# - FROM BOTTOM TOP YOU PERFECT
#
# - FROM BOTTOM TOP YOU PERFECT
#
# - FROM BOTTOM TOP YOU PERFECT
#
# - KEEP CALM
#
# - FROM BOTTOM TOP YOU PERFECT
#
# - CAN THANK GOD NEED
#
# - TONIGHT PERFECT
#
# - IF I KNOW I
#
# - IF PULL HEADPHONES I LISTEN MUSIC I THING LUNGS
#
# - AFTER CAMP NO ONE TELL GOD REAL ALIVE WORLD TODAY
#
# - YOU TAKE CARE GOD BUSINESS GOD TAKE CARE
#
# - DEAR CHILDREN LET US LOVE WORD SPEECH ACTION TRUTH 1 JOHN 3 18 NIV
#
# - THE PERFECT COMBINATION YUMMY LT 3
#
# - IVE COME KNOW MUCH MAINTENANCE TONE BEING FAR EASIER ACCEPT OTHERS
#
# - IS ZOMBIES COME
#
# - YOU ONE COME GO YOU ONE EBB FLOW
#
# - WE WANT KNOW MEASURE MANY IT BECOME IDOL STOP DELIGHT KNOW ONE
#
# - IF GOD SOVEREIGN NOTHING RANDOM
#
# - BE STILL RUNAWAY HEART BE STILL ANXIOUS THOUGHTS BE STILL KNOW GOD ANSWER GOD SOLUTION GOD GOD BE STILL
#
# - I CANNOT HOLD SIN CLAIM I LOVE SEEK SERVE GOD IT WORK LIKE
#
# - YOU ONE COME GO YOU ONE EBB FLOW
#
# - TRUTH CURRY YOUNG TRUTH VIA APP
#
# - NEED PHOTOS TAKE HMU ASAP I GET OPEN SLOT
#
# - TONIGHT START SUN STAND STILL COME JOIN US W
#
# - GO GET MIXTAPE FREE
#
# - S O SUPPORT STAFF
#
# - IF PARENT CHILDREN CHANCES EITHER
#
# - GOD WHISPER US PLEASURES SPEAK CONSCIENCE SHOUT PAIN MEGAPHONE ROUSE DEAF WORLD
#
# - FREE MIXTAPE HOSTED
#
# - BIBLICALLY CHRISTIANS CHURCH AVOIDERS ATTENDERS HOPPERS SHOPPERS BIBLICALLY CHRISTIANS CHURCH MEMBERS
#
# - GOD PICK PURPOSE HE SURPRISE HE CHOOSE
#
# - GOD CREATE NEED LEARN LOVE GOD CREATE SEPARATE
#
# - CONGRATS GOD BLESS BRO UR GONNA GREAT FATHER WOE
#
# - YOU KNOW
#
# - DON CHASE PEOPLE BE THING WORK HARD THE RIGHT PEOPLE BELONG LIFE COME STAY
#
# - SHE INSPIRATION WORLD PROSPER VOICE
#
# - U STILL J NOTEZ THO AKA TAKENOTEZ CHANGE NAME BACK SLIME
#
# - GAME NEED CHANGE
#
# - DON COMPARE PROGRESS OTHERS WE NEED TIME TRAVEL DISTANCE
#
# - THE GREATEST GIFT GET JOY GIVE WATCH
#
# - HAVE EVER CHANGE WHOLE TEXT MESSAGE KNOW SPELL ONE WORD E_E
#
# - OUR SILLY POINTLESS CONVERSATIONS ONES MEAN WORLD LT 3
#
# - LIL WAYNE ENGAGE SNOOKI PREGNANT THE WORLD ACTUALLY GO END YEAR
#
# - HAVE EVER CHANGE WHOLE TEXT MESSAGE KNOW SPELL ONE WORD E_E
#
# - ALL FREAKY PEOPLE MAKE BEAUTY WORLD
#
# - I THINK SCARIEST THING WORLD NEVER KNOW SOMEONE TRUE INTENTIONS
#
# - DO NICEST WAY SAYIN F CK

# %%
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer, mds='tsne')
panel
# Out:
# c:\users\pc-dell\appdata\local\programs\python\python36\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 1      -59.827847  130.827423       1        1  17.350004
# 2      -22.478359   34.839195       2        1  15.882306
# 9      -94.405609 -141.218292       3        1  12.159441
# 0     -194.598465  -65.496346       4        1  10.405037
# 5       33.030849 -154.803711       5        1   8.851407
# 3       90.689240  -33.018974       6        1   8.530080
# 7      -11.018052  -64.031059       7        1   8.502010
# 4     -157.710220   64.754921       8        1   6.967743
# 8     -102.221146  -24.431831       9        1   6.347487
# 6       67.497246   84.030220      10        1   5.004485, topic_info=     Category        Freq      Term       Total  loglift  logprob
# term
# 536   Default  190.000000      love  190.000000  30.0000  30.0000
# 225   Default   93.000000       day   93.000000  29.0000  29.0000
# 392   Default  270.000000       god  270.000000  28.0000  28.0000
# 955   Default   63.000000     watch   63.000000  27.0000  27.0000
# 903   Default   98.000000      time   98.000000  26.0000  26.0000
# 99    Default   58.000000      best   58.000000  25.0000  25.0000
# 622   Default  129.000000    people  129.000000  24.0000  24.0000
# 518   Default   98.000000      like   98.000000  23.0000  23.0000
# 579   Default  115.000000       new  115.000000  22.0000  22.0000
# 994   Default   53.000000       yes   53.000000  21.0000  21.0000
# 524   Default   85.000000      live   85.000000  20.0000  20.0000
# 543   Default  108.000000      make  108.000000  19.0000  19.0000
# 730   Default   40.000000   retweet   40.000000  18.0000  18.0000
# 394   Default   78.000000      good   78.000000  17.0000  17.0000
# 505   Default   77.000000   leaders   77.000000  16.0000  16.0000
# 515   Default  112.000000      life  112.000000  15.0000  15.0000
# 401   Default   47.000000     great   47.000000  14.0000  14.0000
# 941   Default   39.000000     video   39.000000  13.0000  13.0000
# 495   Default   95.000000      know   95.000000  12.0000  12.0000
# 948   Default   30.000000      wait   30.000000  11.0000  11.0000
# 101   Default   38.000000    better   38.000000  10.0000  10.0000
# 833   Default   35.000000      stay   35.000000   9.0000   9.0000
# 390   Default   72.000000      goal   72.000000   8.0000   8.0000
# 182   Default   82.000000      come   82.000000   7.0000   7.0000
# 263   Default   66.000000       don   66.000000   6.0000   6.0000
# 865   Default   42.000000      sure   42.000000   5.0000   5.0000
# 922   Default   40.000000       try   40.000000   4.0000   4.0000
# 966       8  0.745582     welcome
# 971       9  0.933705         win
# 975       2  0.124308        wish
# 975       5  0.870156        wish
# 976       8  0.919427       woman
# 977       7  0.874626       women
# 979       7  0.908812   wonderful
# 980       1  0.066145        word
# 980       2  0.132290        word
# 980       3  0.044097        word
# 980       4  0.463016        word
# 980       7  0.242532        word
# 980       8  0.044097        word
# 982       1  0.814600        work
# 982       7  0.156654        work
# 983       1  0.859204       world
# 983       3  0.104146       world
# 983       7  0.026036       world
# 985       3  0.955311     worship
# 988       6  0.820097       write
# 989       5  0.955957       wrong
# 991       5  0.922702        yeah
# 992       5  0.945504        year
# 993       5  0.270553       years
# 993       8  0.649327       years
# 994       3  0.977127         yes
# 996       5  0.669594       young
# 996       9  0.251098       young
# 998       3  0.117770     youtube
# 998       4  0.824387     youtube
#
# [656 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 3, 10, 1, 6, 4, 8, 5, 9, 7])

# %%
# Construct the k-means clusters
from sklearn.cluster import KMeans
clusters = KMeans(n_clusters=15, random_state=100).fit_predict(lda_output)

# Build the Singular Value Decomposition(SVD) model
from sklearn.decomposition import TruncatedSVD
svd_model = TruncatedSVD(n_components=2)  # 2 components
lda_output_svd = svd_model.fit_transform(lda_output)

# X and Y axes of the plot using SVD decomposition
x = lda_output_svd[:, 0]
y = lda_output_svd[:, 1]

# Plot
plt.figure(figsize=(12, 12))
plt.scatter(x, y, c=clusters)
plt.xlabel('Component 2')
plt.xlabel('Component 1')
plt.title("Segregation of Topic Clusters", )
# Out:
# Text(0.5,1,'Segregation of Topic Clusters')

# %%
#Vectorize transform
text = tf_vectorizer.transform(test_text)

#LDA Transform
topic_probability_scores = lda.transform(text)

for i, doc in enumerate(topic_probability_scores):
    if not np.argmax(doc) == 1:
        print ('Document ' + str(i) + ':')
        print(np.argmax(doc))
        print(test_text[i])
        print(doc)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += "   ".join([feature_names[i]
                            for i in topic.argsort()[:-no_top_words - 1:-1]])
        print(message)
    print()

no_top_words = 12
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic #0: time   new   people   talk   live   listen   forget   word   hard   forgive   check   days
# Topic #1: god   leaders   goal   know   come   way   mean   need   things   church   change   world
# Topic #2: like   make   god   good   life   live   follow   think   happy   feel   start   rt
# Topic #3: people   try   want   don   tell   build   pt   tomorrow   power   know   use   tweet
# Topic #4: best   retweet   vote   little   matter   curry   story   ladies   hear   ur   music   welcome
# Topic #5: love   mind   stand   sin   person   hate   people   year   like   say   god   jesus
# Topic #6: watch   wait   believe   umbrella   gonna   eh   30   round   store   hours   1st   step
# Topic #7: video   better   help   say   faith   real   lord   psalm   looking   new   room   fear
# Topic #8: stay   game   fall   win   play   heart   happen   23   break   leave   alyssa   shall
# Topic #9: day   yes   great   sure   today   let   right   tonight   read   ps   join   don

# %%
new_documents = []
threshold = .8
for index, row in df_document_topic.iterrows():
    best_topic = row['dominant_topic']
    column = 'Topic'+str(int(best_topic))
    if row[column] >= threshold:
        new_documents.append(documents[int(index)])
        
print(len(new_documents))
documents = new_documents
# Out:
# 421
