# %%
documents = []

ego_id = '203226736'

file = open('Textos para testes/egos/' + ego_id + '.txt', 'r', encoding='utf-8')
for line in file:
    documents.append(line)
file.close()
'''
file = open('Textos para testes/alters/' + ego_id + '.txt', 'r', encoding='utf-8')
for line in file:
    documents.append(line)
file.close()
print(len(documents))
'''
# Out:
# "\nfile = open('Textos para testes/alters/' + ego_id + '.txt', 'r', encoding='utf-8')\nfor line in file:\n    documents.append(line)\nfile.close()\nprint(len(documents))\n"

# %%
documents1 = []
j = 0
for t in documents:
    if not t in documents1:
        documents1.append(t)
    else:
        j+=1
        #print(t)
print('Numero de textos repetidos: ' + str(j))
# Out:
# Numero de textos repetidos: 10

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

no_features = 1000 # max number of uniq words

tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
from sklearn.decomposition import LatentDirichletAllocation

no_topics = 4
learning_decay = .7
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0,learning_decay = learning_decay).fit(tf)

# %%
import numpy as np
import pandas as pd

# Show top n keywords for each topic
def show_topics(vectorizer=tf_vectorizer, lda_model=lda, n_words=20):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda_model.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

topic_keywords = show_topics(vectorizer=tf_vectorizer, lda_model=lda, n_words=12)        

# Topic - Keywords Dataframe
df_topic_keywords = pd.DataFrame(topic_keywords)
df_topic_keywords.columns = ['Word '+str(i) for i in range(df_topic_keywords.shape[1])]
df_topic_keywords.index = ['Topic '+str(i) for i in range(df_topic_keywords.shape[0])]
df_topic_keywords
# Out:
#             Word 0      Word 1    Word 2      Word 3      Word 4      Word 5  \
# Topic 0  954590804   president     world          11  1339835893        lake
# Topic 1       want  1339835893  70009161   954590804    16589206        anti
# Topic 2  568825492    25073877     thank  1339835893  1582853809  photograph
# Topic 3      trump   954590804      like     hillary  1339835893        make
#
#            Word 6   Word 7    Word 8      Word 9   Word 10     Word 11
# Topic 0  national      new      year       obama      park  2916305152
# Topic 1  congress      fbi       ask  2294705519  facebook     tonight
# Topic 2     great  hillary  election         day      know  supporters
# Topic 3  25073877     look    report     clinton     today        good

# %%
# column names
topicnames = ["Topic" + str(i) for i in range(no_topics)]

# Topic-Keyword Matrix
df_topic_keywords = pd.DataFrame(np.round(lda.components_, 2))

# Assign Column and Index
df_topic_keywords.columns = tf_vectorizer.get_feature_names()
df_topic_keywords.index = topicnames

# Vie
#list_frames = []
for t, row in df_topic_keywords.iterrows():
    aux = row.nlargest(12)
    #list_frames.append(aux.to_frame().T)
    print(t)
    a = ''
    for word, weight in aux.items():
        a += ' ' + word + ' (' + str(weight) + ') |'
    print(a)
    print('\n')

#list_frames[1]
# Out:
# Topic0
#  954590804 (24.3) | president (6.46) | world (4.56) | 11 (4.45) | 1339835893 (4.1) | lake (3.91) | national (3.7) | new (3.62) | year (3.61) | obama (3.45) | park (3.11) | 2916305152 (2.9) |
#
#
# Topic1
#  want (4.76) | 1339835893 (4.27) | 70009161 (4.07) | 954590804 (3.42) | 16589206 (3.23) | anti (3.11) | congress (3.11) | fbi (3.09) | 2294705519 (3.06) | ask (3.06) | facebook (3.05) | tonight (3.03) |
#
#
# Topic2
#  568825492 (16.91) | 25073877 (8.16) | thank (6.63) | 1339835893 (5.33) | 1582853809 (5.12) | photograph (4.82) | great (4.67) | hillary (3.92) | election (3.58) | day (3.51) | know (3.46) | supporters (3.16) |
#
#
# Topic3
#  trump (16.01) | 954590804 (11.54) | like (10.56) | hillary (9.33) | 1339835893 (8.69) | make (7.9) | 25073877 (6.81) | look (5.96) | report (5.8) | clinton (4.93) | today (4.69) | good (4.01) |

# %%
# Create Document - Topic Matrix
lda_output = lda.transform(tf)

# index names
docnames = [str(i) for i in range(len(documents))]

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 6), columns=topicnames, index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

# Styling
def color_green(val):
   color = 'green' if val > .1 else 'black'
   return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# Apply Style
style = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
style
# Out:
# <style  type="text/css" >
#     #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow0_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow0_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow1_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow1_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow1_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow1_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow1_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow2_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow2_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow2_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow2_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow2_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow3_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow3_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow3_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow3_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow3_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow4_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow4_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow4_col2 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow4_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow4_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow5_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow5_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow5_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow5_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow5_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow6_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow6_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow6_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow6_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow6_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow7_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow7_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow7_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow7_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow7_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow8_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow8_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow8_col2 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow8_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow8_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow9_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow9_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow9_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow9_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow9_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow10_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow10_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow10_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow10_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow10_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow11_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow11_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow11_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow11_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow11_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow12_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow12_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow12_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow12_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898e_782bcbeb671frow12_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_279dc5f8_0f55_11e9_898

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution
# Out:
#    Topic Num  Num Documents
# 0          3            125
# 1          0             99
# 2          2             91
# 3          1             60

# %%
#Documents of topic that classified most documents (First on the table above)

dominant_topic = df_document_topic['dominant_topic']

topic = df_topic_distribution['Topic Num'][0]

test_text = []
j = 0
for i, doc in enumerate(dominant_topic):
    if doc == topic:
        j+=1
        print('- ' + documents[i] + '  ')
        test_text.append(documents[i])
# Out:
# - 954590804 TAKE BREAK ENJOY TEXAS STATE FLOWER BLUEBONNET
#
# - 63717541 ZEKE EMANUEL COMPLAIN RYAN PLAN CAUSE LOWER PREMIUM HIGHER DEDUCTIBLE PLAN HURT PEOPLE
#
# - 15731368 WE TALK RACHEL MADDOW BLUNDER TRUMP WIRETAP CLAIM SLAM NBC
#
# - 3138286292 WE LOVE
#
# - 459872442 NOW MULTI DIMENSIONAL CHESS RIGHT
#
# - 15300388 WATCH A LOT OF PEOPLE INCLUDING HILLARY CLINTON SAID TRUMP HASN PAID TAXES FOR UP TO 20 YEARS
#
# - 954590804 UNLIKELY BEST FRIENDS
#
# - 954590804 ABANDONED YELLOW HOUSE NOVA SCOTIA PHOTO MATT MADDEN KIM VALLIS
#
# - 954590804 ABANDONED SHIP SAND BAR BERMUDA TRIANGLE
#
# - 70009161 THESE PHOTOS TAKE PHOTOGRAPHER CALL GOOD BOY
#
# - 954590804 OUR MOM BEST NIKOLAI ZINOVIEV
#
# - 954590804 THE WIND ROAD PHOTO AMY V MILLER FLICKR
#
# - 954590804 THIS CAT STRANGE UNIQUE FUR PATTERN
#
# - 954590804 A SIMPLE ROAD NORWAY
#
# - 568825492 MEATY GET SECOND CHANCE LOVE STOP SMILE SINCE
#
# - 954590804 DON MAKE ANGRY
#
# - STILL REFUSE SEE SIGN
#
# - 16664681 THE TRUMP ADMINISTRATION WANT OVERHAUL U S TAX CODE AUGUST SAY TREASURY SECRETARY STEVEN MNUCHIN SAY
#
# - 584330930 THE CARTOON EEK MEEK SELL COMPLETE SET ENCYCLOPEDIAS 2 WHY CHEAP ALL FACTS WRONG
#
# - 954590804 GOOD MORNING AWW
#
# - 288363743 I NEVER SEE PRESS CONFERENCE LIKE LIFE REMINISCENT CAPTAIN QUEEG THE CAINE MUTINY TALK STRAWBERRIES
#
# - 954590804 THIS 3 LABRADORS LIKE SLEEP TOGETHER
#
# - 59003 HOW MAKE TIME PASS QUICKLY VIA
#
# - 21922229 WATCH ONE FAVORITE STORIES I TAKE AMSTERDAM MEET DUTCH DONALD TRUMP
#
# - 1041346340 DRAMATIC CAT
#
# - 16895274 IF LOOK SOMETHING WATCH LOOK CHECK
#
# - 1041346340 CAT LOOK LIKE PLAN TAKE WORLD
#
# - 349816997 EASILY ELABORATE RUSSIAN TRUMP TRIBUTE YET
#
# - 1582853809 MARILYN MONROE SIGN AUTOGRAPH FAN SET SOME LIKE IT HOT 1959 PHOTOGRAPH RICHARD MILLER
#
# - 73238146 WHEN HOUSE MARKET CRASH SAW OPPORTUNITY MAKE INVESTORS EVEN MONEY
#
# - 351723025 AM POP TALK TRUMP CLEAN BREXIT REPORT I WRITE
#
# - 112724522 MT LA TIME GOOD REPORT GOVT SET SPECIAL VACCINE INJURY COURT WORK
#
# - 293131808 TODAY REPUBLICANS BEGIN EFFORTS ROLL BACK PROGRESS MAKE
#
# - 498911171 WINSTON CHURCHILL BUST SET OVAL OFFICE RETURN DONALD TRUMP
#
# - 20806622 ATLANTA SNOW MOUNTAIN CLOSE SNOW
#
# - 3119988399 SEARCH INTEREST REPRESENTATIVE SPIKE GOP VOTE HOUSE ETHICS COMMITTEE
#
# - 21608899 SOPHIE SAY HI
#
# - 14780915 DAVY JONES WOULD 71 TODAY HERE 2012 TRIBUTE MONKEE
#
# - 1582853809 PHOTO BOOTH SELF PORTRAIT NORMA JEANE BAKER SOON HOLLYWOOD ICON MARILYN MONROE CIRCA 1940
#
# - 568825492 LOOKS LIKE I COLLECT BEANIE BABIES
#
# - 23401565 NOBODY SAW COME
#
# - 954590804 THE ROAD DEATH VALLEY USA IT STRETCH 200 KILOMETERS STRAIGHT LINE MAZOUZ SHANA
#
# - 90552683 IT 17 YEARS AGO TONIGHT DEUCE BIGALOW MALE GIGOLO PREMIER GLAD MAKE LAUGH WE FUN MAKE
#
# - 294902433 WHOEVER SUPPRESS REPORT FIRE PENTAGON BURY EVIDENCE 125 BILLION WASTE
#
# - 84 CLINTON
#
# - 568825492 SEE PEOPLE HIGH SCHOOL WANT TALK
#
# - 471672239 THX ADVICE JUST SAW VID CBC ELECTION NIGHT SAY TRUMP TRY WIN SOLIDLY DEM MICH
#
# - 78523300 SINCE BUSINESS I LONGER USE SERVICE CONSTITUTIONAL RIGHT FREE SPEECH
#
# - 203226736 VOTE I WOULD LIKE SOMEONE ELSE PUT CHARGE CURATING NEWS BEHALF CULL UNTRUTHFUL INFORMATION
#
# - 802137370598457344 COFFEE BAD COFFEE GOOD
#
# - 777550083386646529 EGGS BAD EGGS GOOD
#
# - 568825492 IF CAT DOG GET MARRY LOOK LIKE
#
# - 568825492 TRY FIND RIGHT SELFIE ANGLE LIKE
#
# - 369875107 THE HOURLY SUN 03 03 47 UTC VISIT INFO
#
# - 18643437 CNN FAKE NEWS REPORTER CONFUSE ISLAM ISLAMISM DELETES TWEET
#
# - 20605323 WATCH SUNDAY ABC 9AM CBS 10 30AM
#
# - 70009161 UR SLEEP FRIENDS HOUSE PLAY MUCH
#
# - 17400407 RT WHEN TELL USE COLOR PENCIL MAKE PORTRAIT
#
# - 30313925 1 MILLION AMERICANS SELECT PLAN FIRST 12 DAYS OPEN ENROLLMENT JOIN
#
# - 742143 WHAT LIKE INDEPENDENT POLITICIAN COMMUNIST CHINA OUR TEAM TRY FIND
#
# - 2890961 DON SLEEP PHONE
#
# - 369875107 THE HOURLY SUN 07 03 52 PM UTC VISIT INFO
#
# - 1317381 JUST WATCH LAST EPISODES REFRESH QUALITY REPORT
#
# - 811942160 THE KID RIGHT YAZIDI ONE 2000 ABDUCTED YAZIDI CHILDREN ISIL GET TRAIN JIHADISTS
#
# - 312199170 TO WIN TRUMP NEED HOLLYWOOD CELEBS POLITICAL MACHINE HE NEED BUY SMALL TOWNS LIKE
#
# - 14529929 TRUMP RALLY TODAY FL NC PA NH MI SINCE CONVENTION TRUMP HOLD CAMPAIGN EVENTS 21 STATE SPEND TIME OH FL PA
#
# - WATCH
#
# - 1339835893 TODAY I ASK VOTE TOMORROW LET MAKE HISTORY TOGETHER HILLARY
#
# - 954590804 TURTLE SHELL LOOK LIKE FIREWORKS DISPLAY BEAUTIFUL PHOTO FARGIONEORAZIO 500PX
#
# - 3232054991 CHUCKTODD WHAT STATUS FBI INVESTIGATION CLINTON FOUNDATION
#
# - 25073877 AFTER DECADES LIE SCANDAL CROOKED HILLARY CORRUPTION CLOSE
#
# - THIS TRUMP EFFECT
#
# - 500168147 MONTREAL POLICE SPY LA PRESSE REPORTER PATRICK LAGACÉ
#
# - 25073877 HILLARY DEMS LOVE PRAISE FBI DIRECTOR COMEY DAYS AGO ORIGINAL EVIDENCE OVERWHELM DELAY
#
# - 725861265613053954 LET US GOOD WORK TODAY
#
# - 954590804 22 ANIMALS THAT TOTALLY LOOK LIKE CELEBRITIES
#
# - 708039673684295680 TRUMP STAR PROTECTOR WOMAN NAME DENISE SCOTT
#
# - 620571475 LIVE WANT SEE MOVEMENT LIKE NEVER SEE THE OVERFLOW CROWD OUTSIDE VENUE
#
# - 1339835893 EQUALITY BALLOT
#
# - JUSTICE BALLOT
#
# - OUR PROGRESS BALLOT
#
# - 493678717 JUST FUN I LOOK BACK CAP CAMPAIGN
#
# - 1339835893 WORDS ADVICE 1969 COLLEGE COMMENCEMENT SPEAKER HILLARY RODHAM
#
# - 2916305152 NEW REPORT IF USE TRACK SINCE 1987 SECRETLY SELL COP WITHOUT WARRANT
#
# - 1339835893 IT IMPORTANT GIVE SOMETHING VOTE HILLARY
#
# - 1339835893 WE GO WORK HEARTS MAKE HILLARY CLINTON NEXT PRESIDENT UNITED STATES
#
# - 25073877 GET VOTE 11 8 2016
#
# - TRUMP 43
#
# - CLINTON 41
#
# - 1339835893 WHEN COME POLICY PLAN COMPARE HILLARY TRUMP
#
# - 25073877 OBAMACARE PREMIUMS INCREASE 33 PENNSYLVANIA COMPLETE DISASTER IT MUST REPEAL REPLACE
#
# - 1925121408 TUNE LATEST TAKE POLL ONE QUESTION REALLY LOOK PREDICT ELECTION RESULT WTOP
#
# - 568825492 YOU GET AWAY ANYTHING LOOK
#
# - 69773058 THERE BARGAIN EVEN SUGGEST JOHN KIRBY STATE DEPT SPOX CLAIM QUID PRO QUO DISCUSSION CONTRADICTS MULTIPLE FBI REPORT
#
# - 25073877 WE WONDER HILLARY AVOID PROSECUTION EMAIL SCHEME WIKILEAKS MAY FIND ANSWER OBAMA
#
# - 1339835893 WHEN TRUMP PENCE ATTACK PLANNED PARENTHOOD ATTACK MILLIONS AMERICANS
#
# - 16589206 BAD JOURNALISM THE USE HACK EMAIL SPECULATION WE MANY SOURCE STATE METHODS USE OBTAIN PART
#
# - 1339835893 WE COME FAR TURN BACK MAKE SURE REGISTER VOTE
#
# - 568825492 QUALITY CONTENT I LIKE SEE
#
# - 1339835893 IN 2001 HILLARY WORK SUPPORT REBUILD NEW YORK 9 11 TRUMP POCKET EMERGENCY FUND
#
# - 12524522 WHY LOVE EXPLAIN
#
# - 1339835893 WE URGE VOTERS DUMP TRUMP CHOOSE CLEARLY QUALIFY CANDIDATE RACE HILLARY CLINTON DENVERPOST
#
# - 25073877 THANK PENNSYLVANIA THIS MOVEMENT LIKE NEVER SEE 11 8 16 TOGETHER
#
# - 954590804 WHO READY PHOTO JUUSOHD PORVOO
#
# - 3214214153 VIA THOUSANDS GATHER OUTSIDE TRUMP TOWER SUPPORT THE PEOPLE CHOICE NEX
#
# - 203226736 FROM I SEE REPORT I ENJOY FIND INTEREST
#
# - 25073877 HERE STATEMENT
#
# - 1339835893 WOMEN POWER STOP TRUMP
#
# - 19073744 COMING NEXT TALK
#
# - 747855867626856449 JUST SHOW THE UNCONDEMNED MOVIE I PROUDLY CONSULT HEADING EVENT WORK HOP
#
# - 1339835893 WHEN TRUMP CALL AMERICA THIRD WORLD COUNTRY TELL LOT LISTEN ACTUALLY
#
# - 18005848 SHARYL GIVE BRILLIANT TED TALK ASTROTURF IT PRETTY VICIOUS CRAP I LIKE DILBERT
#
# - 2916305152 IN STATEMENT AVOID CALL REPORT FALSE PREFER MEANINGLESS MISLEAD COMPARE YAHOO WOR
#
# - 25073877 THANK ARIZONA THIS MOVEMENT LIKE NOBODY EVER SEE TOGETHER GO MAKE AMERICA SAFE
#
# - NO WONDER TRUMP PICK
#
# - 1339835893 TRUMP STAND DEBATE STAGE LIE MILLIONS AMERICANS
#
# - CHIP MAKE SURE NEVER BECOME PRESIDENT
#
# - 75736238 12 PEOPLE SHOW HILLARY RALLY COME NO ONE BUY HILLARY WIN POINT GAME OVER
#
# - 954590804 RUSSIAN PHOTOGRAPHER VADIM TRUNOV CAPTURE TINY CREATURES NORMALLY GO UNSEEN
#
# - 15846407 I LOVE TIME I GET SPEND AND CALL PINHEAD
#
# - 85144671 BEVERLY HILLBILLIES DEBUT 54 YEARS AGO TODAY CBS
#
# - 1339835893 OUR CHOICE HILLARY CLINTON RECORD SERVICE RAFT PRAGMATIC IDEAS NYTIMES ENDORSE HILLARY
#
# - 25073877 THANK ROANOKE VIRGINIA MOVEMENT JOIN US TODAY
#
# - SIGN
#
# - 25073877 LOOKING FORWARD MEET BENJAMIN NETANYAHU TRUMP TOWER 10 00 A M

# %%
#Vectorize transform
text = tf_vectorizer.transform(test_text)

#LDA Transform
topic_probability_scores = lda.transform(text)

for i, doc in enumerate(topic_probability_scores):
    if not np.argmax(doc) == 1:
        print ('Document ' + str(i) + ':')
        print(np.argmax(doc))
        print(test_text[i])
        print(doc)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += "   ".join([feature_names[i].replace('aa','@')
                            for i in topic.argsort()[:-no_top_words - 1:-1]])
        print(message)
    print()

no_top_words = 12
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic #0: 954590804   president   world   11   1339835893   lake   national   new   year   obama   park   2916305152
# Topic #1: want   1339835893   70009161   954590804   16589206   anti   congress   fbi   ask   2294705519   facebook   tonight
# Topic #2: 568825492   25073877   thank   1339835893   1582853809   photograph   great   hillary   election   day   know   supporters
# Topic #3: trump   954590804   like   hillary   1339835893   make   25073877   look   report   clinton   today   good

# %%
file = open('Textos para testes/egos/' + ego_id + '.txt', 'r', encoding='utf-8')
fonte = file.readlines()

autor = '1582853809'
for i in fonte:
    if autor in i:
        print(i)
# Out:
# 1582853809 AT SEGREGATE DRINK FOUNTAIN MOBILE ALABAMA 1956 PHOTOGRAPH GORDON PARKS
#
# 1582853809 MARILYN MONROE SIGN AUTOGRAPH FAN SET SOME LIKE IT HOT 1959 PHOTOGRAPH RICHARD MILLER
#
# 1582853809 MUHAMMAD ALI TRAIN 1974 PHOTOGRAPH KEN REGAN
#
# 1582853809 THE FIRST KNOW PHOTOGRAPH PRESIDENTIAL INAUGURATION PRESIDENT JAMES BUCHANAN MARCH 1857
#
# 1582853809 A MUSLIM WOMAN COVER YELLOW STAR JEWISH NEIGHBOR VEIL PROTECT SARAJEVO 1941
#
# 1582853809 A DAREDEVIL BALANCE BACK LEGS CHAIR ATOP FURNITURE 20 STORIES NEW YORK CIRCA 1920 PHOTO
#
# 1582853809 CZESLAWA KWOKA AGE 14 AUSCHWITZ PRISONER IDENTITY PHOTO DECEMBER 1942 PHOTOGRAPH WILHELM BRASSE
#
# 1582853809 SENATOR HIRAM RHODES REVELS FIRST AFRICAN AMERICAN SIT US SENATE CIRCA 1870 PHOTOGRAPH MATHEW BRADY
#
# 1582853809 PHOTO BOOTH SELF PORTRAIT NORMA JEANE BAKER SOON HOLLYWOOD ICON MARILYN MONROE CIRCA 1940
#
# 1582853809 FORMER UNITED STATES SECRETARY STATE COLIN POWELL SELFIES 60 YEARS FACEBOOK FOLKS
#
# 1582853809 EIGHTEEN YEAR OLD INVENTOR H DAY WEAR HEADPHONES ATTACH WIRELESS TOP HAT 1922

# %%
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda, tf, tf_vectorizer, mds='tsne')
panel
# Out:
# c:\users\pc-dell\appdata\local\programs\python\python37\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=                x           y  topics  cluster       Freq
# topic
# 3       47.172672 -362.084503       1        1  34.244754
# 2      276.189331 -292.695801       2        1  23.883294
# 0      -22.217518 -133.068283       3        1  22.262701
# 1      206.799118  -63.679634       4        1  19.609250, topic_info=     Category       Freq        Term      Total  loglift  logprob
# term
# 37    Default  33.000000   954590804  33.000000  30.0000  30.0000
# 32    Default  18.000000   568825492  18.000000  29.0000  29.0000
# 348   Default  16.000000       trump  16.000000  28.0000  28.0000
# 268   Default   7.000000   president   7.000000  27.0000  27.0000
# 201   Default  12.000000        like  12.000000  26.0000  26.0000
# 338   Default   8.000000       thank   8.000000  25.0000  25.0000
# 25    Default  15.000000    25073877  15.000000  24.0000  24.0000
# 193   Default   4.000000        lake   4.000000  23.0000  23.0000
# 381   Default   6.000000       world   6.000000  22.0000  22.0000
# 156   Default   5.000000       great   5.000000  21.0000  21.0000
# 11    Default   7.000000  1582853809   7.000000  20.0000  20.0000
# 34    Default   6.000000    70009161   6.000000  19.0000  19.0000
# 366   Default   8.000000        want   8.000000  18.0000  18.0000
# 229   Default   4.000000    national   4.000000  17.0000  17.0000
# 5     Default   6.000000          11   6.000000  16.0000  16.0000
# 238   Default   4.000000       obama   4.000000  15.0000  15.0000
# 49    Default   3.000000        anti   3.000000  14.0000  14.0000
# 205   Default   6.000000        look   6.000000  13.0000  13.0000
# 254   Default   7.000000  photograph   7.000000  12.0000  12.0000
# 100   Default   3.000000    congress   3.000000  11.0000  11.0000
# 50    Default   3.000000         ask   3.000000  10.0000  10.0000
# 382   Default   5.000000        year   5.000000   9.0000   9.0000
# 12    Default   4.000000    16589206   4.000000   8.0000   8.0000
# 132   Default   4.000000    facebook   4.000000   7.0000   7.0000
# 106   Default   4.000000         day   4.000000   6.0000   6.0000
# 22    Default   4.000000  2294705519   4.000000   5.0000   5.0000
# 167   Default  13.000000     hillary  13.000000   4.0000   4.0000
# 342   Default   4.000000     tonight   4.000000   3.0000   3.0000
# 233   Default   7.000000         new   7.000000   2.0000   2.0000
# 191   Default   4.000000        know   4.000000   1.0000   1.0000
# ...       ...        ...         ...        ...      ...      ...
# 134    Topic4   1.403280        fail   2.747121   0.9574  -5.3134
# 151    Topic4   1.438185      future   2.885556   0.9328  -5.2888
# 84     Topic4   1.863802       check   3.789529   0.9195  -5.0296
# 72     Topic4   1.411372       build   2.871366   0.9189  -5.3077
# 61     Topic4   1.379719        bank   2.833250   0.9096  -5.3303
# 120    Topic4   1.328006       dream   2.729515   0.9087  -5.3685
# 160    Topic4   1.303182      hawaii   2.680310   0.9080  -5.3874
# 82     Topic4   1.350126      change   2.800690   0.8995  -5.3520
# 87     Topic4   1.563958         cia   3.257773   0.8953  -5.2050
# 351    Topic4   1.246093  underneath   2.595909   0.8952  -5.4322
# 34     Topic4   3.090983    70009161   6.465276   0.8912  -4.5237
# 51     Topic4   1.293306        atop   2.711062   0.8890  -5.3950
# 115    Topic4   1.730086        docs   3.627501   0.8888  -5.1040
# 91     Topic4   1.247395       clark   2.662415   0.8710  -5.4312
# 211    Topic4   1.225506         man   2.644337   0.8601  -5.4489
# 139    Topic4   1.251681       final   2.744340   0.8441  -5.4277
# 176    Topic4   1.252409         ice   2.770160   0.8353  -5.4271
# 366    Topic4   3.613093        want   8.023686   0.8313  -4.3677
# 137    Topic4   2.348546         fbi   5.507394   0.7769  -4.7984
# 327    Topic4   1.613480       story   3.677365   0.8054  -5.1738
# 216    Topic4   1.881752        meet   4.437967   0.7712  -5.0200
# 204    Topic4   1.744772      little   4.076820   0.7805  -5.0956
# 279    Topic4   1.737358       rally   4.356399   0.7099  -5.0999
# 234    Topic4   1.821133        news   4.821933   0.6555  -5.0528
# 375    Topic4   1.817956       woman   4.972812   0.6229  -5.0545
# 233    Topic4   2.241549         new   7.788922   0.3836  -4.8450
# 7      Topic4   3.240299  1339835893  19.063378  -0.1429  -4.4766
# 253    Topic4   2.201725       photo   9.159488   0.2036  -4.8630
# 37     Topic4   2.597838   954590804  33.980975  -0.9420  -4.6975
# 380    Topic4   1.753441        work   6.866765   0.2641  -5.0906
#
# [201 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 1         2  0.586318         000
# 2         1  0.575780          03
# 2         3  0.287890          03
# 5         1  0.298000          11
# 5         2  0.149000          11
# 5         3  0.595999          11
# 7         1  0.419653  1339835893
# 7         2  0.209826  1339835893
# 7         3  0.157370  1339835893
# 7         4  0.157370  1339835893
# 11        1  0.282250  1582853809
# 11        2  0.564500  1582853809
# 11        4  0.141125  1582853809
# 12        1  0.217263    16589206
# 12        4  0.434527    16589206
# 14        3  0.697633  1707369648
# 22        1  0.235334  2294705519
# 22        3  0.235334  2294705519
# 22        4  0.470667  2294705519
# 24        2  0.540873  2361224263
# 24        3  0.270437  2361224263
# 25        1  0.397154    25073877
# 25        2  0.463346    25073877
# 25        3  0.066192    25073877
# 25        4  0.066192    25073877
# 26        1  0.384261  2916305152
# 26        2  0.192131  2916305152
# 26        3  0.384261  2916305152
# 26        4  0.192131  2916305152
# 31        2  0.621508   564028464
# ...     ...       ...         ...
# 355       3  0.175309         use
# 362       1  0.688421        vote
# 362       2  0.172105        vote
# 362       3  0.172105        vote
# 362       4  0.172105        vote
# 366       1  0.249262        want
# 366       2  0.124631        want
# 366       3  0.124631        want
# 366       4  0.498524        want
# 368       1  0.678348       watch
# 368       4  0.169587       watch
# 370       3  0.535248         way
# 370       4  0.267624         way
# 371       1  0.261603        week
# 371       2  0.523207        week
# 371       3  0.261603        week
# 374       1  0.576665         win
# 375       1  0.201093       woman
# 375       2  0.201093       woman
# 375       3  0.201093       woman
# 375       4  0.402187       woman
# 380       1  0.436887        work
# 380       3  0.291258        work
# 380       4  0.291258        work
# 381       1  0.312672       world
# 381       3  0.625344       world
# 382       2  0.197491        year
# 382       3  0.592473        year
# 382       4  0.197491        year
# 386       2  0.695423       young
#
# [338 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 1, 2])

# %%
# Construct the k-means clusters
from sklearn.cluster import KMeans
clusters = KMeans(n_clusters=15, random_state=100).fit_predict(lda_output)

# Build the Singular Value Decomposition(SVD) model
from sklearn.decomposition import TruncatedSVD
svd_model = TruncatedSVD(n_components=2)  # 2 components
lda_output_svd = svd_model.fit_transform(lda_output)

# X and Y axes of the plot using SVD decomposition
x = lda_output_svd[:, 0]
y = lda_output_svd[:, 1]

# Plot
plt.figure(figsize=(12, 12))
plt.scatter(x, y, c=clusters)
plt.xlabel('Component 2')
plt.xlabel('Component 1')
plt.title("Segregation of Topic Clusters", )
# Out:
# Text(0.5, 1.0, 'Segregation of Topic Clusters')

# %%
#Separando novos documentos baseado nos pesos do LDA

new_documents = []
threshold = .8
for index, row in df_document_topic.iterrows():
    best_topic = row['dominant_topic']
    column = 'Topic'+str(int(best_topic))
    if row[column] >= threshold:
        new_documents.append(documents[int(index)])
        
print(len(new_documents))
documents = new_documents
# Out:
# 139
