# %%
documents = []

file = open('Tratando Arquivos/nytimes.txt', 'r')
for line in file:
    documents.append(line)
file.close()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

no_features = 200 # max number of uniq words

tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation

no_topics = 7
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tf)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                            for i in topic.argsort()[:-no_top_words - 1:-1]])
        print(message)
    print()

# %%
no_top_words = 5
display_topics(nmf, tf_feature_names, no_top_words)
# Out:
# Topic #0: brett sexual kavanaugh assault accused
# Topic #1: said yes night sesame best
# Topic #2: know briefing day need end
# Topic #3: trump president legal war nearly
# Topic #4: south korea north china jong
# Topic #5: emmys winners list complete red
# Topic #6: hill judge anita kavanaugh writes

# %%
import pandas as pd
import numpy as np
   
# Create Document - Topic Matrix
nmf_output = nmf.transform(tf)

# column names
topicnames = ["Topic" + str(i) for i in range(no_topics)]

# index names
docnames = ["Doc" + str(i) for i in range(len(documents))]

# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(nmf_output, 6), columns=topicnames, index=docnames)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic

# Styling
def color_green(val):
   color = 'green' if val > .1 else 'black'
   return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# Apply Style
df_document_topics = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style  type="text/css" >
#     #T_d326d5a4_c354_11e8_9921_782bcbeb671frow0_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow0_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow0_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow0_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow0_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow0_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow1_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow1_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow1_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow1_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow1_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow1_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow1_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow1_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow2_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow2_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow2_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow2_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow2_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow2_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow2_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow2_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow3_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow3_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow3_col2 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow3_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow3_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow3_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow3_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow3_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow4_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow4_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow4_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow4_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow4_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow4_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow4_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow4_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow5_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow5_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow5_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow5_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow5_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow5_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow5_col6 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow5_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow6_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow6_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow6_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow6_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow6_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow6_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow6_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow6_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow7_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow7_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow7_col2 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow7_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow7_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow7_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow7_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow7_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671frow8_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_d326d5a4_c354_11e8_9921_782bcbeb671fr

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution
# Out:
#    Topic Num  Num Documents
# 0          0             37
# 1          5             33
# 2          1             31
# 3          4             25
# 4          3             25
# 5          2             11
# 6          6              7

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Construct the k-means clusters
from sklearn.cluster import KMeans
clusters = KMeans(n_clusters=15, random_state=100).fit_predict(nmf_output)

# Build the Singular Value Decomposition(SVD) model
from sklearn.decomposition import TruncatedSVD
svd_model = TruncatedSVD(n_components=2)  # 2 components
nmf_output_svd = svd_model.fit_transform(nmf_output)

# X and Y axes of the plot using SVD decomposition
x = nmf_output_svd[:, 0]
y = nmf_output_svd[:, 1]

# Plot
plt.figure(figsize=(12, 12))
plt.scatter(x, y, c=clusters)
plt.xlabel('Component 2')
plt.xlabel('Component 1')
plt.title("Segregation of Topic Clusters", )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5f14ae669048> in <module>()
#      13
#      14 # Plot
# ---> 15 plt.figure(figsize=(12, 12))
#      16 plt.scatter(x, y, c=clusters)
#      17 plt.xlabel('Component 2')
#
# NameError: name 'plt' is not defined

# %%
df_document_topics
# Out:
# <style  type="text/css" >
#     #T_dd953342_c354_11e8_84cd_782bcbeb671frow0_col0 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow0_col1 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow0_col2 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow0_col3 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow0_col4 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow0_col5 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow0_col6 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow0_col7 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow1_col0 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow1_col1 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow1_col2 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow1_col3 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow1_col4 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow1_col5 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow1_col6 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow1_col7 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow2_col0 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow2_col1 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow2_col2 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow2_col3 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow2_col4 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow2_col5 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow2_col6 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow2_col7 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow3_col0 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow3_col1 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow3_col2 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow3_col3 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow3_col4 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow3_col5 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow3_col6 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow3_col7 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow4_col0 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow4_col1 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow4_col2 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow4_col3 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow4_col4 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow4_col5 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow4_col6 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow4_col7 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow5_col0 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow5_col1 {
#             color:  green;
#             font-weight:  700;
#             color:  green;
#             font-weight:  700;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow5_col2 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow5_col3 {
#             color:  black;
#             font-weight:  400;
#             color:  black;
#             font-weight:  400;
#         }    #T_dd953342_c354_11e8_84cd_782bcbeb671frow5_col4 {
